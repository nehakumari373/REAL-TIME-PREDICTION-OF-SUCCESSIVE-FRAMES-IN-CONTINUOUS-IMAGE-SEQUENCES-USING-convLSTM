# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization, Conv3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Load frames from a folder (Fix sorting issue)
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    # Get only valid image files
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Extract numbers safely and sort
    def extract_number(filename):
        parts = filename.split('.')
        try:
            return int(parts[0])  # Extract numeric prefix
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)  # Sort based on numbers

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  # Take seq_length frames as input
        Y.append(frames[i+seq_length])   # Next frame as output
    X = np.expand_dims(np.array(X), axis=-1)  # Add channel dimension
    Y = np.expand_dims(np.array(Y), axis=-1)  # Add channel dimension
    return X, Y

# Load dataset
folder_path = "MNNEW/initial5"  # Update with your actual folder path
frames = load_frames(folder_path)
X, Y = prepare_data(frames)

# Reshape input and output
X = X.reshape((X.shape[0], X.shape[1], X.shape[2], X.shape[3], 1))  # (batch_size, 5, 128, 128, 1)
Y = Y.reshape((Y.shape[0], 1, Y.shape[1], Y.shape[2], 1))  # (batch_size, 1, 128, 128, 1)
# Build ConvLSTM Model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True, input_shape=(5, 128, 128, 1)),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=False),  # Last ConvLSTM2D (No return_sequences)
    BatchNormalization(),

    # Fix: Ensure correct shape before Conv3D
    Reshape((1, 128, 128, 64)),  # Converts 4D -> 5D

    Conv3D(filters=1, kernel_size=(3,3,3), activation='sigmoid', padding='same')  # Output (1, 128, 128, 1)
])

# Compile Model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Model Summary
print(model.summary())
# Model checkpoint
checkpoint = ModelCheckpoint("convLSTM_model9_fixed.keras", save_best_only=True)

# Train the model
#model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])
history = model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])


# Save model 
model.save("convLSTM_model9_fixed.keras")

# Predict and Evaluate
predictions = model.predict(X)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # Ensure correct range

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Print Average Accuracy
print(f"Average SSIM Score: {np.mean(ssim_scores):.4f}")
print(f"Average MSE Score: {np.mean(mse_scores):.4f}")

# Display Sample Results
idx = np.random.randint(len(predictions))  # Select a random index
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(Y[idx].squeeze(), cmap='gray')
plt.title("Actual Frame")

plt.subplot(1, 2, 2)
plt.imshow(predictions[idx].squeeze(), cmap='gray')
plt.title("Predicted Frame")

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 5, 128, 128, 64)     │         150,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 5, 128, 128, 64)     │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Training vs Validation Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Function to plot actual vs predicted results dynamically
def plot_results(num_results=5):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")

        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call function to plot results dynamically
num_frames_to_plot = 5  # Change this to any number of results you want
plot_results(num_frames_to_plot)

# %%
# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # SSIM for similarity

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  # SSIM as percentage
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Score: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")
# Out:
# 🔹 Average SSIM Score: 65.40%
# 🔹 Average MSE Score: 0.0204

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Function to load frames from a folder
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    def extract_number(filename):
        try:
            return int(filename.split('.')[0])  # Extract numeric part
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Function to prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  
        Y.append(frames[i+seq_length])   
    X = np.expand_dims(np.array(X), axis=-1)  
    Y = np.expand_dims(np.array(Y), axis=-1)  
    return X, Y

# Load trained model
model = tf.keras.models.load_model("convLSTM_model9_fixed.keras")

# Load new dataset (Update folder path)
new_folder_path = "data_sets101/initial_frames101_03"  # Change this to your actual test folder path
test_frames = load_frames(new_folder_path)
X_test, Y_test = prepare_data(test_frames)

# Reshape data
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], X_test.shape[3], 1))
Y_test = Y_test.reshape((Y_test.shape[0], 1, Y_test.shape[1],  Y_test.shape[2], 1))

# Predict using trained model
predictions = model.predict(X_test)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y_test[i].squeeze()
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Accuracy: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")

# Function to plot results dynamically
def plot_results(num_results=4):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y_test[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")
        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call the function with a dynamic number of results (change as needed)
num_frames_to_plot = 6  # Change this value to plot a different number of results
plot_results(num_frames_to_plot)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# 🔹 Average SSIM Accuracy: 69.00%
# 🔹 Average MSE Score: 0.0158

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization, Conv3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Load frames from a folder (Fix sorting issue)
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    # Get only valid image files
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Extract numbers safely and sort
    def extract_number(filename):
        parts = filename.split('.')
        try:
            return int(parts[0])  # Extract numeric prefix
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)  # Sort based on numbers

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  # Take seq_length frames as input
        Y.append(frames[i+seq_length])   # Next frame as output
    X = np.expand_dims(np.array(X), axis=-1)  # Add channel dimension
    Y = np.expand_dims(np.array(Y), axis=-1)  # Add channel dimension
    return X, Y

# Load dataset
folder_path = "MNNEW/initial5"  # Update with your actual folder path
frames = load_frames(folder_path)
X, Y = prepare_data(frames)

# Reshape input and output
X = X.reshape((X.shape[0], X.shape[1], X.shape[2], X.shape[3], 1))  # (batch_size, 5, 128, 128, 1)
Y = Y.reshape((Y.shape[0], 1, Y.shape[1], Y.shape[2], 1))  # (batch_size, 1, 128, 128, 1)
# Build ConvLSTM Model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True, input_shape=(5, 128, 128, 1)),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=False),  # Last ConvLSTM2D (No return_sequences)
    BatchNormalization(),

    # Fix: Ensure correct shape before Conv3D
    Reshape((1, 128, 128, 64)),  # Converts 4D -> 5D

    Conv3D(filters=1, kernel_size=(3,3,3), activation='sigmoid', padding='same')  # Output (1, 128, 128, 1)
])

# Compile Model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Model Summary
print(model.summary())
# Model checkpoint
checkpoint = ModelCheckpoint("convLSTM_model10_fixed.keras", save_best_only=True)

# Train the model
#model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])
history = model.fit(X, Y, epochs=150, batch_size=8, validation_split=0.2, callbacks=[checkpoint])


# Save model 
model.save("convLSTM_model10_fixed.keras")

# Predict and Evaluate
predictions = model.predict(X)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # Ensure correct range

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Print Average Accuracy
print(f"Average SSIM Score: {np.mean(ssim_scores):.4f}")
print(f"Average MSE Score: {np.mean(mse_scores):.4f}")

# Display Sample Results
idx = np.random.randint(len(predictions))  # Select a random index
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(Y[idx].squeeze(), cmap='gray')
plt.title("Actual Frame")

plt.subplot(1, 2, 2)
plt.imshow(predictions[idx].squeeze(), cmap='gray')
plt.title("Predicted Frame")

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 5, 128, 128, 64)     │         150,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 5, 128, 128, 64)     │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Training vs Validation Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Function to plot actual vs predicted results dynamically
def plot_results(num_results=5):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")

        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call function to plot results dynamically
num_frames_to_plot = 5  # Change this to any number of results you want
plot_results(num_frames_to_plot)

# %%
# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # SSIM for similarity

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  # SSIM as percentage
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Score: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")
# Out:
# 🔹 Average SSIM Score: 60.45%
# 🔹 Average MSE Score: 0.0300

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Function to load frames from a folder
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    def extract_number(filename):
        try:
            return int(filename.split('.')[0])  # Extract numeric part
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")
    
    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Function to prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  
        Y.append(frames[i+seq_length])   
    X = np.expand_dims(np.array(X), axis=-1)  
    Y = np.expand_dims(np.array(Y), axis=-1)  
    return X, Y

# Load trained model
model = tf.keras.models.load_model("convLSTM_model10_fixed.keras")

# Load new dataset (Update folder path)
new_folder_path = "data_sets101/initial_frames101_03"  # Change this to your actual test folder path
test_frames = load_frames(new_folder_path)
X_test, Y_test = prepare_data(test_frames)

# Reshape data
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], X_test.shape[3], 1))
Y_test = Y_test.reshape((Y_test.shape[0], 1, Y_test.shape[1],  Y_test.shape[2], 1))

# Predict using trained model
predictions = model.predict(X_test)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y_test[i].squeeze()
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Accuracy: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")

# Function to plot results dynamically
def plot_results(num_results=4):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y_test[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")
        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call the function with a dynamic number of results (change as needed)
num_frames_to_plot = 6  # Change this value to plot a different number of results
plot_results(num_frames_to_plot)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# 🔹 Average SSIM Accuracy: 66.28%
# 🔹 Average MSE Score: 0.0294

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization, Conv3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Load frames from a folder (Fix sorting issue)
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    # Get only valid image files
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Extract numbers safely and sort
    def extract_number(filename):
        parts = filename.split('.')
        try:
            return int(parts[0])  # Extract numeric prefix
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)  # Sort based on numbers

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=4):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  # Take seq_length frames as input
        Y.append(frames[i+seq_length])   # Next frame as output
    X = np.expand_dims(np.array(X), axis=-1)  # Add channel dimension
    Y = np.expand_dims(np.array(Y), axis=-1)  # Add channel dimension
    return X, Y

# Load dataset
folder_path = "MNNEW/initial5"  # Update with your actual folder path
frames = load_frames(folder_path)
X, Y = prepare_data(frames)

# Reshape input and output
X = X.reshape((X.shape[0], X.shape[1], X.shape[2], X.shape[3], 1))  # (batch_size, 5, 128, 128, 1)
Y = Y.reshape((Y.shape[0], 1, Y.shape[1], Y.shape[2], 1))  # (batch_size, 1, 128, 128, 1)
# Build ConvLSTM Model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True, input_shape=(5, 128, 128, 1)),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=False),  # Last ConvLSTM2D (No return_sequences)
    BatchNormalization(),

    # Fix: Ensure correct shape before Conv3D
    Reshape((1, 128, 128, 64)),  # Converts 4D -> 5D

    Conv3D(filters=1, kernel_size=(3,3,3), activation='sigmoid', padding='same')  # Output (1, 128, 128, 1)
])

# Compile Model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Model Summary
print(model.summary())
# Model checkpoint
checkpoint = ModelCheckpoint("convLSTM_model11_fixed.keras", save_best_only=True)

# Train the model
#model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])
history = model.fit(X, Y, epochs=10, batch_size=8, validation_split=0.2, callbacks=[checkpoint])


# Save model 
model.save("convLSTM_model11_fixed.keras")

# Predict and Evaluate
predictions = model.predict(X)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # Ensure correct range

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Print Average Accuracy
print(f"Average SSIM Score: {np.mean(ssim_scores):.4f}")
print(f"Average MSE Score: {np.mean(mse_scores):.4f}")

# Display Sample Results
idx = np.random.randint(len(predictions))  # Select a random index
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(Y[idx].squeeze(), cmap='gray')
plt.title("Actual Frame")

plt.subplot(1, 2, 2)
plt.imshow(predictions[idx].squeeze(), cmap='gray')
plt.title("Predicted Frame")

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 5, 128, 128, 64)     │         150,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 5, 128, 128, 64)     │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Training vs Validation Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Function to plot actual vs predicted results dynamically
def plot_results(num_results=5):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")

        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call function to plot results dynamically
num_frames_to_plot = 5  # Change this to any number of results you want
plot_results(num_frames_to_plot)

# %%
# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  # SSIM for similarity

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  # SSIM as percentage
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Score: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")
# Out:
# 🔹 Average SSIM Score: 42.52%
# 🔹 Average MSE Score: 0.0876

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Function to load frames from a folder
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    def extract_number(filename):
        try:
            return int(filename.split('.')[0])  # Extract numeric part
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")
    
    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Function to prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  
        Y.append(frames[i+seq_length])   
    X = np.expand_dims(np.array(X), axis=-1)  
    Y = np.expand_dims(np.array(Y), axis=-1)  
    return X, Y

# Load trained model
model = tf.keras.models.load_model("convLSTM_model11_fixed.keras")

# Load new dataset (Update folder path)
new_folder_path = "data_sets101/initial_frames101_03"  # Change this to your actual test folder path
test_frames = load_frames(new_folder_path)
X_test, Y_test = prepare_data(test_frames)

# Reshape data
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], X_test.shape[3], 1))
Y_test = Y_test.reshape((Y_test.shape[0], 1, Y_test.shape[1],  Y_test.shape[2], 1))

# Predict using trained model
predictions = model.predict(X_test)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y_test[i].squeeze()
    predicted = predictions[i].squeeze()

    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, data_range=1.0)  

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Convert SSIM to percentage
average_ssim = np.mean(ssim_scores) * 100  
average_mse = np.mean(mse_scores)

print(f"🔹 Average SSIM Accuracy: {average_ssim:.2f}%")
print(f"🔹 Average MSE Score: {average_mse:.4f}")

# Function to plot results dynamically
def plot_results(num_results=4):
    num_results = min(num_results, len(predictions))  # Ensure we don't exceed available data

    plt.figure(figsize=(10, 2 * num_results))

    for i in range(num_results):
        plt.subplot(num_results, 2, 2*i+1)
        plt.imshow(Y_test[i].squeeze(), cmap='gray')
        plt.title(f"Actual Frame {i+1}")
        plt.subplot(num_results, 2, 2*i+2)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title(f"Predicted Frame {i+1}")

    plt.tight_layout()
    plt.show()

# Call the function with a dynamic number of results (change as needed)
num_frames_to_plot = 6  # Change this value to plot a different number of results
plot_results(num_frames_to_plot)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 🔹 Average SSIM Accuracy: 51.45%
# 🔹 Average MSE Score: 0.0985

# %%
# Load frames from a folder (Fix sorting issue)
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    # Get only valid image files
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Extract numbers safely and sort
    def extract_number(filename):
        parts = filename.split('.')
        try:
            return int(parts[0])  # Extract numeric prefix
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)  # Sort based on numbers

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)  # Load color images (RGB)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  # Take seq_length frames as input
        Y.append(frames[i+seq_length])   # Next frame as output
    X = np.expand_dims(np.array(X), axis=-1)  # Add channel dimension
    Y = np.expand_dims(np.array(Y), axis=-1)  # Add channel dimension
    return X, Y

# Load dataset
folder_path = "MNNEW/initial5"  # Update with your actual folder path
frames = load_frames(folder_path)
X, Y = prepare_data(frames)

# Reshape input and output
X = X.reshape((X.shape[0], X.shape[1], X.shape[2], X.shape[3], 3))  # (batch_size, 5, 128, 128, 3) for RGB
Y = Y.reshape((Y.shape[0], 1, Y.shape[1], Y.shape[2], 3))  # (batch_size, 1, 128, 128, 3)

# Build ConvLSTM Model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True, input_shape=(5, 128, 128, 3)),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=False),  # Last ConvLSTM2D (No return_sequences)
    BatchNormalization(),

    # Fix: Ensure correct shape before Conv3D
    Reshape((1, 128, 128, 64)),  # Converts 4D -> 5D

    Conv3D(filters=3, kernel_size=(3,3,3), activation='sigmoid', padding='same')  # Output (1, 128, 128, 3) for RGB
])

# Compile Model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Model Summary
print(model.summary())

# Model checkpoint
checkpoint = ModelCheckpoint("convLSTM_model12_fixed.keras", save_best_only=True)

# Train the model
#model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])
history = model.fit(X, Y, epochs=3, batch_size=8, validation_split=0.2, callbacks=[checkpoint])

# Save model 
model.save("convLSTM_model12_fixed.keras")

# Predict and Evaluate
predictions = model.predict(X)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, multichannel=True, data_range=1.0)  # Ensure correct range for color images

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)

# Print Average Accuracy
print(f"Average SSIM Score: {np.mean(ssim_scores):.4f}")
print(f"Average MSE Score: {np.mean(mse_scores):.4f}")

# Display Sample Results
idx = np.random.randint(len(predictions))  # Select a random index
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(Y[idx].squeeze())
plt.title("Actual Frame")

plt.subplot(1, 2, 2)
plt.imshow(predictions[idx].squeeze())
plt.title("Predicted Frame")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 46
#      44 # Load dataset
#      45 folder_path = "MNNEW/initial5"  # Update with your actual folder path
# ---> 46 frames = load_frames(folder_path)
#      47 X, Y = prepare_data(frames)
#      49 # Reshape input and output
#
# Cell In[1], line 6, in load_frames(folder, img_size)
#       3 frames = []
#       5 # Get only valid image files
# ----> 6 files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
#       8 # Extract numbers safely and sort
#       9 def extract_number(filename):
#
# NameError: name 'os' is not defined

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization, Conv3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

# Load frames from a folder (Fix sorting issue)
def load_frames(folder, img_size=(128, 128)):
    frames = []
    
    # Get only valid image files
    files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Extract numbers safely and sort
    def extract_number(filename):
        parts = filename.split('.')
        try:
            return int(parts[0])  # Extract numeric prefix
        except ValueError:
            return float('inf')  # Push non-numeric files to the end

    files = sorted(files, key=extract_number)  # Sort based on numbers

    for file in files:
        img_path = os.path.join(folder, file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Unable to read {img_path}")
            continue

        img = cv2.resize(img, img_size)
        frames.append(img)

    if not frames:
        raise ValueError("No valid images found in the folder.")

    return np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0,1]

# Prepare dataset for next-frame prediction
def prepare_data(frames, seq_length=5):
    X, Y = [], []
    for i in range(len(frames) - seq_length):
        X.append(frames[i:i+seq_length])  # Take seq_length frames as input
        Y.append(frames[i+seq_length])   # Next frame as output
    X = np.expand_dims(np.array(X), axis=-1)  # Add channel dimension
    Y = np.expand_dims(np.array(Y), axis=-1)  # Add channel dimension
    return X, Y

# Load dataset
folder_path = "MNNEW/initial5"  # Update with your actual folder path
frames = load_frames(folder_path)
X, Y = prepare_data(frames)

# Reshape input and output
X = X.reshape((X.shape[0], X.shape[1], X.shape[2], X.shape[3], 1))  # (batch_size, 5, 128, 128, 1)
Y = Y.reshape((Y.shape[0], 1, Y.shape[1], Y.shape[2], 1))  # (batch_size, 1, 128, 128, 1)
# Build ConvLSTM Model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True, input_shape=(5, 128, 128, 1)),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=True),
    BatchNormalization(),

    ConvLSTM2D(filters=64, kernel_size=(3,3), padding='same', return_sequences=False),  # Last ConvLSTM2D (No return_sequences)
    BatchNormalization(),

    # Fix: Ensure correct shape before Conv3D
    Reshape((1, 128, 128, 64)),  # Converts 4D -> 5D

    Conv3D(filters=3, kernel_size=(3,3,3), activation='sigmoid', padding='same')  # Output (1, 128, 128, 1)
])

# Compile Model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Model Summary
print(model.summary())
# Model checkpoint
checkpoint = ModelCheckpoint("convLSTM_model12_fixed.keras", save_best_only=True)

# Train the model
#model.fit(X, Y, epochs=250, batch_size=8, validation_split=0.2, callbacks=[checkpoint])
history = model.fit(X, Y, epochs=3, batch_size=8, validation_split=0.2, callbacks=[checkpoint])


# Save model 
model.save("convLSTM_model12_fixed.keras")

# Predict and Evaluate
predictions = model.predict(X)

# Compute Accuracy Metrics
mse_scores, ssim_scores = [], []

for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted, multichannel=True, data_range=1.0)  # Ensure correct range for color images

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)
'''
for i in range(len(predictions)):
    actual = Y[i].squeeze()  # Remove extra dimensions
    predicted = predictions[i].squeeze()
    
    mse = mean_squared_error(actual, predicted)
    ssim_score = ssim(actual, predicted,multichannel=True, data_range=1.0)  # Ensure correct range

    mse_scores.append(mse)
    ssim_scores.append(ssim_score)
'''
# Print Average Accuracy
print(f"Average SSIM Score: {np.mean(ssim_scores):.4f}")
print(f"Average MSE Score: {np.mean(mse_scores):.4f}")

# Display Sample Results
idx = np.random.randint(len(predictions))  # Select a random index
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(Y[idx].squeeze())
plt.title("Actual Frame")

plt.subplot(1, 2, 2)
plt.imshow(predictions[idx].squeeze())
plt.title("Predicted Frame")

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_9 (ConvLSTM2D)           │ (None, 5, 128, 128, 64)     │         150,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 5, 128, 128, 64)     │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ...
